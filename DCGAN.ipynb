# %%
from PIL import Image

import torch
import torch.nn as nn
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torchvision.utils import save_image

import numpy as np
import matplotlib.pyplot as plt
import random

import os

from model import Generator, Discriminator

# %%
def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    # For reproducibility (may slow down training)
    # torch.backends.cudnn.deterministic = True
    # torch.backends.cudnn.benchmark = False

# %%
set_seed(42)

# %%
device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
# get mnist data
data_dir = './data'
os.makedirs(data_dir,exist_ok=True)
mnist_train_dataset = datasets.MNIST(data_dir, train=True, download=True, transform=transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))]))

# %%
# plot 9 random sample images from a mnist dataset (train or test)
def plot_9_sample_images(dataset):
    fig, axs = plt.subplots(3, 3)
    indices = np.random.choice(len(dataset), 9)
    for i, idx in enumerate(indices):
        axs[np.unravel_index(i, (3,3))].imshow(dataset[idx][0].squeeze(), cmap="gray")
        axs[np.unravel_index(i, (3,3))].set_title(f"label={dataset[idx][1]}")
        axs[np.unravel_index(i, (3,3))].set_axis_off()
    plt.show()
    

plot_9_sample_images(mnist_train_dataset)

# %%
# compute losses


def discriminator_loss(batch_real_data, batch_gen_data, discriminator_model):
    loss = nn.BCEWithLogitsLoss()
    logits_real = discriminator_model(batch_real_data)
    logits_fake = discriminator_model(batch_gen_data)
    loss_D  = loss(logits_real, torch.ones_like(logits_real).to(device)) + loss(logits_fake, torch.zeros_like(logits_fake).to(device))
    return loss_D, logits_real, logits_fake

def discriminator_wasserstein_loss(batch_real_data, batch_gen_data, discriminator_model):
    pass

def generator_loss(z, discriminator_model, generator_model):
    loss = nn.BCEWithLogitsLoss()
    batch_gen_data = generator_model(z)
    logits_fake = discriminator_model(batch_gen_data) 
    return loss(logits_fake, torch.ones_like(logits_fake).to(device))

# %%
# weights initialization
def weights_init_dcgan(m):    
    if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d, nn.Linear)):
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        if m.bias is not None:
            nn.init.constant_(m.bias.data, 0)

    elif isinstance(m, nn.BatchNorm1d) or isinstance(m, nn.BatchNorm2d):
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %%
# define model
generator = Generator()
generator.to(device)

discriminator = Discriminator()
discriminator.to(device)

generator.apply(weights_init_dcgan)
discriminator.apply(weights_init_dcgan)
# Out:
# Discriminator(
#   (down1): Conv2d(1, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (down2): Conv2d(256, 512, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (out): Conv2d(512, 1, kernel_size=(7, 7), stride=(1, 1))
# )

# %%
learning_rate = 2e-4
batch_size = 64
epochs = 10

# %%
train_dataloader = DataLoader(mnist_train_dataset, batch_size=batch_size)

# %%
# Display image and label.
print(f"length of the dataloader = {len(train_dataloader)}")
train_features, train_labels = next(iter(train_dataloader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
# Out:
# length of the dataloader = 938
# Feature batch shape: torch.Size([64, 1, 28, 28])
# Labels batch shape: torch.Size([64])

# %%
# optimizer
betas = (0.5, 0.999)
optimizer_G = torch.optim.Adam(generator.parameters(), learning_rate, betas)
optimizer_D = torch.optim.Adam(discriminator.parameters(), learning_rate, betas)

# %%
def update_D(real_data, gen_data, discriminator, number_of_update, optimizer_D):
    loss = 0
    D_real = 0
    D_fake = 0
    
    for i in range(number_of_update):
        optimizer_D.zero_grad()
        loss_D, logits_real, logits_fake = discriminator_loss(real_data, gen_data, discriminator)
        loss_D.backward()
        optimizer_D.step()
        loss = loss_D.item()
        with torch.no_grad():
            D_real = torch.sigmoid(logits_real).mean().item()
            D_fake = torch.sigmoid(logits_fake).mean().item()
        
    return loss, D_real, D_fake
    
        
def update_G(z, discriminator, generator, number_of_update, optimizer_G):
    loss = 0
    for i in range(number_of_update):
        optimizer_G.zero_grad()
        loss_G = generator_loss(z, discriminator, generator)
        loss_G.backward()
        optimizer_G.step()
        loss = loss_G.item()
    return loss

# %%
def training_loop(generator, discriminator, train_dataloader, epochs, batch_size, optimizer_G, optimizer_D):
    
    z_fixed = torch.randn(64, 100, device=device)
    os.makedirs("./output/samples",exist_ok=True)
    losses_D = []
    losses_G = []
    D_real_hist = []
    D_fake_hist = []

    for epoch in range(epochs):
        
        epoch_loss_D = 0 
        epoch_loss_G = 0 
        epoch_D_real = 0.0
        epoch_D_fake = 0.0
      
        generator.eval()
        with torch.no_grad():
            fake = generator(z_fixed).cpu()
        fake = (fake + 1) / 2  # [-1,1] → [0,1]
        save_image(fake, f"./output/samples/epoch_{epoch+1:03d}.png", nrow=8,  normalize=False)
        generator.train()
        
        for i, data in enumerate(train_dataloader):
            real_data, _ = data
            real_data = real_data.to(device)
            z = torch.rand((real_data.shape[0], 100)).to(device)
            gen_data = generator(z)
            gen_data_detached = gen_data.detach()

            loss_D, D_real, D_fake = update_D(real_data, gen_data_detached, discriminator, 1, optimizer_D)
            loss_G = update_G(z, discriminator, generator, 1, optimizer_G)
            
            epoch_loss_D += loss_D / len(train_dataloader)
            epoch_loss_G += loss_G / len(train_dataloader)
            epoch_D_real += D_real / len(train_dataloader)
            epoch_D_fake += D_fake / len(train_dataloader)
            
            if i%50==0:
                print(f'Epoch/Batch_index {epoch+1}/{i} batch_loss_D {loss_D:.3f}, batch_loss_G {loss_G:.3f}')
        losses_D.append(epoch_loss_D)
        losses_G.append(epoch_loss_G)
        D_real_hist.append(epoch_D_real)
        D_fake_hist.append(epoch_D_fake)

        print(
        f"Epoch {epoch+1:03d} | "
        f"Loss D: {epoch_loss_D:.4f} | "
        f"Loss G: {epoch_loss_G:.4f} | "
        f"D(real): {epoch_D_real:.3f} | "
        f"D(fake): {epoch_D_fake:.3f}"
        )
    
    return losses_D, losses_G, D_real_hist, D_fake_hist

# %%
losses_D, losses_G, D_real_hist, D_fake_hist = training_loop(generator, discriminator, train_dataloader, epochs, batch_size, optimizer_G, optimizer_D)
# Out:
# Epoch/Batch_index 1/0 batch_loss_D 2.134, batch_loss_G 9.490
# Epoch/Batch_index 1/50 batch_loss_D 2.152, batch_loss_G 10.360
# Epoch/Batch_index 1/100 batch_loss_D 1.184, batch_loss_G 1.223
# Epoch/Batch_index 1/150 batch_loss_D 1.270, batch_loss_G 1.322
# Epoch/Batch_index 1/200 batch_loss_D 0.910, batch_loss_G 2.442
# Epoch/Batch_index 1/250 batch_loss_D 1.108, batch_loss_G 0.744
# Epoch/Batch_index 1/300 batch_loss_D 0.912, batch_loss_G 0.635
# Epoch/Batch_index 1/350 batch_loss_D 0.478, batch_loss_G 1.665
# Epoch/Batch_index 1/400 batch_loss_D 0.604, batch_loss_G 2.889
# Epoch/Batch_index 1/450 batch_loss_D 0.347, batch_loss_G 2.584
# Epoch/Batch_index 1/500 batch_loss_D 0.880, batch_loss_G 4.713
# Epoch/Batch_index 1/550 batch_loss_D 0.525, batch_loss_G 2.211
# Epoch/Batch_index 1/600 batch_loss_D 0.500, batch_loss_G 2.753
# Epoch/Batch_index 1/650 batch_loss_D 0.713, batch_loss_G 1.257
# Epoch/Batch_index 1/700 batch_loss_D 1.824, batch_loss_G 4.470
# Epoch/Batch_index 1/750 batch_loss_D 1.048, batch_loss_G 2.012
# Epoch/Batch_index 1/800 batch_loss_D 1.097, batch_loss_G 1.643
# Epoch/Batch_index 1/850 batch_loss_D 1.650, batch_loss_G 2.812
# Epoch/Batch_index 1/900 batch_loss_D 0.755, batch_loss_G 1.855
# Epoch 001 | Loss D: 0.9169 | Loss G: 2.8332 | D(real): 0.736 | D(fake): 0.266
# Epoch/Batch_index 2/0 batch_loss_D 1.743, batch_loss_G 0.925
# Epoch/Batch_index 2/50 batch_loss_D 1.559, batch_loss_G 0.484
# Epoch/Batch_index 2/100 batch_loss_D 1.202, batch_loss_G 0.822
# Epoch/Batch_index 2/150 batch_loss_D 1.128, batch_loss_G 3.207
# Epoch/Batch_index 2/200 batch_loss_D 1.005, batch_loss_G 2.508
# Epoch/Batch_index 2/250 batch_loss_D 0.942, batch_loss_G 2.481
# Epoch/Batch_index 2/300 batch_loss_D 0.940, batch_loss_G 1.274
# Epoch/Batch_index 2/350 batch_loss_D 0.838, batch_loss_G 2.092
# Epoch/Batch_index 2/400 batch_loss_D 0.911, batch_loss_G 1.853
# Epoch/Batch_index 2/450 batch_loss_D 0.634, batch_loss_G 2.223
# Epoch/Batch_index 2/500 batch_loss_D 1.507, batch_loss_G 1.969
# Epoch/Batch_index 2/550 batch_loss_D 0.842, batch_loss_G 1.866
# Epoch/Batch_index 2/600 batch_loss_D 1.203, batch_loss_G 1.345
# Epoch/Batch_index 2/650 batch_loss_D 0.899, batch_loss_G 1.403
# Epoch/Batch_index 2/700 batch_loss_D 0.943, batch_loss_G 2.132
# Epoch/Batch_index 2/750 batch_loss_D 1.194, batch_loss_G 1.936
# Epoch/Batch_index 2/800 batch_loss_D 1.338, batch_loss_G 1.859
# Epoch/Batch_index 2/850 batch_loss_D 0.972, batch_loss_G 1.329
# Epoch/Batch_index 2/900 batch_loss_D 1.198, batch_loss_G 0.906
# Epoch 002 | Loss D: 1.0814 | Loss G: 1.6745 | D(real): 0.658 | D(fake): 0.342
# Epoch/Batch_index 3/0 batch_loss_D 1.867, batch_loss_G 0.914
# Epoch/Batch_index 3/50 batch_loss_D 1.038, batch_loss_G 1.794
# Epoch/Batch_index 3/100 batch_loss_D 1.375, batch_loss_G 1.208
# Epoch/Batch_index 3/150 batch_loss_D 1.028, batch_loss_G 2.263
# Epoch/Batch_index 3/200 batch_loss_D 1.192, batch_loss_G 2.032
# Epoch/Batch_index 3/250 batch_loss_D 1.202, batch_loss_G 1.189
# Epoch/Batch_index 3/300 batch_loss_D 1.245, batch_loss_G 0.919
# Epoch/Batch_index 3/350 batch_loss_D 1.112, batch_loss_G 0.545
# Epoch/Batch_index 3/400 batch_loss_D 1.049, batch_loss_G 1.357
# Epoch/Batch_index 3/450 batch_loss_D 0.809, batch_loss_G 1.859
# Epoch/Batch_index 3/500 batch_loss_D 1.536, batch_loss_G 1.930
# Epoch/Batch_index 3/550 batch_loss_D 0.999, batch_loss_G 2.148
# Epoch/Batch_index 3/600 batch_loss_D 1.015, batch_loss_G 1.512
# Epoch/Batch_index 3/650 batch_loss_D 1.261, batch_loss_G 0.959
# Epoch/Batch_index 3/700 batch_loss_D 0.990, batch_loss_G 1.549
# Epoch/Batch_index 3/750 batch_loss_D 1.120, batch_loss_G 1.375
# Epoch/Batch_index 3/800 batch_loss_D 1.343, batch_loss_G 1.754
# Epoch/Batch_index 3/850 batch_loss_D 1.241, batch_loss_G 1.030
# Epoch/Batch_index 3/900 batch_loss_D 1.119, batch_loss_G 0.972
# Epoch 003 | Loss D: 1.1683 | Loss G: 1.4607 | D(real): 0.626 | D(fake): 0.374
# Epoch/Batch_index 4/0 batch_loss_D 1.871, batch_loss_G 0.542
# Epoch/Batch_index 4/50 batch_loss_D 1.193, batch_loss_G 1.080
# Epoch/Batch_index 4/100 batch_loss_D 1.353, batch_loss_G 1.439
# Epoch/Batch_index 4/150 batch_loss_D 1.036, batch_loss_G 2.062
# Epoch/Batch_index 4/200 batch_loss_D 1.106, batch_loss_G 1.977
# Epoch/Batch_index 4/250 batch_loss_D 1.305, batch_loss_G 1.105
# Epoch/Batch_index 4/300 batch_loss_D 1.144, batch_loss_G 1.147
# Epoch/Batch_index 4/350 batch_loss_D 1.187, batch_loss_G 1.403
# Epoch/Batch_index 4/400 batch_loss_D 1.230, batch_loss_G 1.482
# Epoch/Batch_index 4/450 batch_loss_D 1.069, batch_loss_G 2.170
# Epoch/Batch_index 4/500 batch_loss_D 1.721, batch_loss_G 1.801
# Epoch/Batch_index 4/550 batch_loss_D 1.074, batch_loss_G 0.955
# Epoch/Batch_index 4/600 batch_loss_D 1.263, batch_loss_G 1.127
# Epoch/Batch_index 4/650 batch_loss_D 1.108, batch_loss_G 1.037
# Epoch/Batch_index 4/700 batch_loss_D 1.030, batch_loss_G 1.233
# Epoch/Batch_index 4/750 batch_loss_D 1.168, batch_loss_G 1.012
# Epoch/Batch_index 4/800 batch_loss_D 1.363, batch_loss_G 1.190
# Epoch/Batch_index 4/850 batch_loss_D 1.116, batch_loss_G 1.049
# Epoch/Batch_index 4/900 batch_loss_D 1.125, batch_loss_G 0.949
# Epoch 004 | Loss D: 1.2222 | Loss G: 1.3274 | D(real): 0.604 | D(fake): 0.396
# Epoch/Batch_index 5/0 batch_loss_D 2.197, batch_loss_G 0.406
# Epoch/Batch_index 5/50 batch_loss_D 1.310, batch_loss_G 0.705
# Epoch/Batch_index 5/100 batch_loss_D 1.374, batch_loss_G 0.950
# Epoch/Batch_index 5/150 batch_loss_D 1.078, batch_loss_G 1.829
# Epoch/Batch_index 5/200 batch_loss_D 1.319, batch_loss_G 1.267
# Epoch/Batch_index 5/250 batch_loss_D 1.252, batch_loss_G 1.577
# Epoch/Batch_index 5/300 batch_loss_D 1.246, batch_loss_G 0.903
# Epoch/Batch_index 5/350 batch_loss_D 1.240, batch_loss_G 0.732
# Epoch/Batch_index 5/400 batch_loss_D 1.205, batch_loss_G 1.280
# Epoch/Batch_index 5/450 batch_loss_D 0.900, batch_loss_G 2.058
# Epoch/Batch_index 5/500 batch_loss_D 1.699, batch_loss_G 1.453
# Epoch/Batch_index 5/550 batch_loss_D 1.143, batch_loss_G 1.309
# Epoch/Batch_index 5/600 batch_loss_D 1.234, batch_loss_G 1.267
# Epoch/Batch_index 5/650 batch_loss_D 1.150, batch_loss_G 1.273
# Epoch/Batch_index 5/700 batch_loss_D 1.186, batch_loss_G 1.512
# Epoch/Batch_index 5/750 batch_loss_D 1.209, batch_loss_G 1.126
# Epoch/Batch_index 5/800 batch_loss_D 1.304, batch_loss_G 1.507
# Epoch/Batch_index 5/850 batch_loss_D 1.180, batch_loss_G 1.325
# Epoch/Batch_index 5/900 batch_loss_D 1.138, batch_loss_G 1.200
# Epoch 005 | Loss D: 1.2449 | Loss G: 1.2672 | D(real): 0.594 | D(fake): 0.406
# Epoch/Batch_index 6/0 batch_loss_D 2.118, batch_loss_G 0.466
# Epoch/Batch_index 6/50 batch_loss_D 1.199, batch_loss_G 1.136
# Epoch/Batch_index 6/100 batch_loss_D 1.298, batch_loss_G 0.741
# Epoch/Batch_index 6/150 batch_loss_D 1.056, batch_loss_G 1.911
# Epoch/Batch_index 6/200 batch_loss_D 1.391, batch_loss_G 0.978
# Epoch/Batch_index 6/250 batch_loss_D 1.305, batch_loss_G 1.384
# Epoch/Batch_index 6/300 batch_loss_D 1.381, batch_loss_G 0.922
# Epoch/Batch_index 6/350 batch_loss_D 1.298, batch_loss_G 0.934
# Epoch/Batch_index 6/400 batch_loss_D 1.199, batch_loss_G 1.279
# Epoch/Batch_index 6/450 batch_loss_D 1.009, batch_loss_G 1.518
# Epoch/Batch_index 6/500 batch_loss_D 1.747, batch_loss_G 1.171
# Epoch/Batch_index 6/550 batch_loss_D 1.110, batch_loss_G 1.286
# Epoch/Batch_index 6/600 batch_loss_D 1.273, batch_loss_G 1.213
# Epoch/Batch_index 6/650 batch_loss_D 1.218, batch_loss_G 1.114
# Epoch/Batch_index 6/700 batch_loss_D 1.151, batch_loss_G 1.406
# Epoch/Batch_index 6/750 batch_loss_D 1.198, batch_loss_G 0.941
# Epoch/Batch_index 6/800 batch_loss_D 1.283, batch_loss_G 1.462
# Epoch/Batch_index 6/850 batch_loss_D 1.209, batch_loss_G 1.129
# Epoch/Batch_index 6/900 batch_loss_D 1.169, batch_loss_G 1.049
# Epoch 006 | Loss D: 1.2718 | Loss G: 1.2223 | D(real): 0.585 | D(fake): 0.415
# Epoch/Batch_index 7/0 batch_loss_D 1.639, batch_loss_G 0.580
# Epoch/Batch_index 7/50 batch_loss_D 1.265, batch_loss_G 0.991
# Epoch/Batch_index 7/100 batch_loss_D 1.385, batch_loss_G 1.112
# Epoch/Batch_index 7/150 batch_loss_D 0.942, batch_loss_G 1.597
# Epoch/Batch_index 7/200 batch_loss_D 1.410, batch_loss_G 0.835
# Epoch/Batch_index 7/250 batch_loss_D 1.344, batch_loss_G 1.378
# Epoch/Batch_index 7/300 batch_loss_D 1.314, batch_loss_G 1.105
# Epoch/Batch_index 7/350 batch_loss_D 1.258, batch_loss_G 0.964
# Epoch/Batch_index 7/400 batch_loss_D 1.382, batch_loss_G 1.688
# Epoch/Batch_index 7/450 batch_loss_D 1.137, batch_loss_G 1.858
# Epoch/Batch_index 7/500 batch_loss_D 1.670, batch_loss_G 1.049
# Epoch/Batch_index 7/550 batch_loss_D 1.096, batch_loss_G 1.323
# Epoch/Batch_index 7/600 batch_loss_D 1.278, batch_loss_G 1.151
# Epoch/Batch_index 7/650 batch_loss_D 1.278, batch_loss_G 1.157
# Epoch/Batch_index 7/700 batch_loss_D 1.198, batch_loss_G 1.608
# Epoch/Batch_index 7/750 batch_loss_D 1.446, batch_loss_G 0.622
# Epoch/Batch_index 7/800 batch_loss_D 1.480, batch_loss_G 1.584
# Epoch/Batch_index 7/850 batch_loss_D 1.238, batch_loss_G 1.048
# Epoch/Batch_index 7/900 batch_loss_D 1.084, batch_loss_G 1.103
# Epoch 007 | Loss D: 1.2851 | Loss G: 1.1803 | D(real): 0.578 | D(fake): 0.422
# Epoch/Batch_index 8/0 batch_loss_D 1.964, batch_loss_G 0.558
# Epoch/Batch_index 8/50 batch_loss_D 1.235, batch_loss_G 1.051
# Epoch/Batch_index 8/100 batch_loss_D 1.286, batch_loss_G 0.757
# Epoch/Batch_index 8/150 batch_loss_D 1.203, batch_loss_G 1.624
# Epoch/Batch_index 8/200 batch_loss_D 1.232, batch_loss_G 1.079
# Epoch/Batch_index 8/250 batch_loss_D 1.364, batch_loss_G 0.985
# Epoch/Batch_index 8/300 batch_loss_D 1.246, batch_loss_G 0.768
# Epoch/Batch_index 8/350 batch_loss_D 1.387, batch_loss_G 0.711
# Epoch/Batch_index 8/400 batch_loss_D 1.255, batch_loss_G 1.274
# Epoch/Batch_index 8/450 batch_loss_D 1.347, batch_loss_G 2.350
# Epoch/Batch_index 8/500 batch_loss_D 1.883, batch_loss_G 1.297
# Epoch/Batch_index 8/550 batch_loss_D 1.075, batch_loss_G 1.388
# Epoch/Batch_index 8/600 batch_loss_D 1.401, batch_loss_G 1.081
# Epoch/Batch_index 8/650 batch_loss_D 1.319, batch_loss_G 0.906
# Epoch/Batch_index 8/700 batch_loss_D 1.192, batch_loss_G 0.892
# Epoch/Batch_index 8/750 batch_loss_D 1.369, batch_loss_G 0.865
# Epoch/Batch_index 8/800 batch_loss_D 1.380, batch_loss_G 0.974
# Epoch/Batch_index 8/850 batch_loss_D 1.234, batch_loss_G 0.889
# Epoch/Batch_index 8/900 batch_loss_D 1.136, batch_loss_G 1.239
# Epoch 008 | Loss D: 1.2995 | Loss G: 1.1489 | D(real): 0.572 | D(fake): 0.428
# Epoch/Batch_index 9/0 batch_loss_D 1.811, batch_loss_G 0.435
# Epoch/Batch_index 9/50 batch_loss_D 1.413, batch_loss_G 0.807
# Epoch/Batch_index 9/100 batch_loss_D 1.296, batch_loss_G 0.872
# Epoch/Batch_index 9/150 batch_loss_D 1.034, batch_loss_G 1.549
# Epoch/Batch_index 9/200 batch_loss_D 1.341, batch_loss_G 1.023
# Epoch/Batch_index 9/250 batch_loss_D 1.341, batch_loss_G 0.883
# Epoch/Batch_index 9/300 batch_loss_D 1.424, batch_loss_G 0.919
# Epoch/Batch_index 9/350 batch_loss_D 1.362, batch_loss_G 0.752
# Epoch/Batch_index 9/400 batch_loss_D 1.343, batch_loss_G 1.380
# Epoch/Batch_index 9/450 batch_loss_D 1.219, batch_loss_G 1.376
# Epoch/Batch_index 9/500 batch_loss_D 1.858, batch_loss_G 1.156
# Epoch/Batch_index 9/550 batch_loss_D 1.153, batch_loss_G 1.085
# Epoch/Batch_index 9/600 batch_loss_D 1.181, batch_loss_G 1.291
# Epoch/Batch_index 9/650 batch_loss_D 1.270, batch_loss_G 1.213
# Epoch/Batch_index 9/700 batch_loss_D 1.228, batch_loss_G 0.994
# Epoch/Batch_index 9/750 batch_loss_D 1.349, batch_loss_G 0.763
# Epoch/Batch_index 9/800 batch_loss_D 1.476, batch_loss_G 1.499
# Epoch/Batch_index 9/850 batch_loss_D 1.292, batch_loss_G 1.476
# Epoch/Batch_index 9/900 batch_loss_D 1.324, batch_loss_G 1.200
# Epoch 009 | Loss D: 1.3137 | Loss G: 1.1181 | D(real): 0.566 | D(fake): 0.433
# Epoch/Batch_index 10/0 batch_loss_D 1.593, batch_loss_G 0.502
# Epoch/Batch_index 10/50 batch_loss_D 1.337, batch_loss_G 0.901
# Epoch/Batch_index 10/100 batch_loss_D 1.414, batch_loss_G 0.792
# Epoch/Batch_index 10/150 batch_loss_D 1.139, batch_loss_G 1.274
# Epoch/Batch_index 10/200 batch_loss_D 1.543, batch_loss_G 0.772
# Epoch/Batch_index 10/250 batch_loss_D 1.477, batch_loss_G 1.056
# Epoch/Batch_index 10/300 batch_loss_D 1.411, batch_loss_G 0.894
# Epoch/Batch_index 10/350 batch_loss_D 1.369, batch_loss_G 0.733
# Epoch/Batch_index 10/400 batch_loss_D 1.232, batch_loss_G 1.289
# Epoch/Batch_index 10/450 batch_loss_D 1.112, batch_loss_G 1.430
# Epoch/Batch_index 10/500 batch_loss_D 1.729, batch_loss_G 1.021
# Epoch/Batch_index 10/550 batch_loss_D 1.259, batch_loss_G 0.979
# Epoch/Batch_index 10/600 batch_loss_D 1.391, batch_loss_G 1.272
# Epoch/Batch_index 10/650 batch_loss_D 1.284, batch_loss_G 0.975
# Epoch/Batch_index 10/700 batch_loss_D 1.160, batch_loss_G 1.239
# Epoch/Batch_index 10/750 batch_loss_D 1.326, batch_loss_G 0.832
# Epoch/Batch_index 10/800 batch_loss_D 1.343, batch_loss_G 1.131
# Epoch/Batch_index 10/850 batch_loss_D 1.176, batch_loss_G 1.277
# Epoch/Batch_index 10/900 batch_loss_D 1.279, batch_loss_G 1.020
# Epoch 010 | Loss D: 1.3156 | Loss G: 1.1028 | D(real): 0.564 | D(fake): 0.436

# %%
plt.figure(figsize=(8, 5))
plt.plot(losses_D, label="Discriminator", linewidth=2)
plt.plot(losses_G, label="Generator", linewidth=2)

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("DCGAN Training Losses")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig("training_losses.png", dpi=150)
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.plot(D_real_hist, label="D(real)")
plt.plot(D_fake_hist, label="D(fake)")
plt.axhline(0.5, linestyle="--", color="gray")

plt.xlabel("Epoch")
plt.ylabel("Probability")
plt.title("Discriminator Confidence")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig("discriminator_confidence.png", dpi=150)
plt.show()

# %%
# see what is generated 
z = torch.rand(9,100).to(device)

generator.eval()
generated_images = generator(z)
generated_images = generated_images.cpu()
print(generated_images.shape)

fig, axs = plt.subplots(3, 3)
for i in range(generated_images.shape[0]):
    axs[np.unravel_index(i, (3,3))].imshow(generated_images[i].squeeze().detach().numpy(), cmap="gray")
    axs[np.unravel_index(i, (3,3))].set_axis_off()
plt.show()
# Out:
# torch.Size([9, 1, 28, 28])
