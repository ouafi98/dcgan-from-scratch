# %%
from PIL import Image

import torch
import torch.nn as nn
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torchvision.utils import save_image

import numpy as np
import matplotlib.pyplot as plt
import random

import os

from model import Generator, Discriminator

# %%
def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    # For reproducibility (may slow down training)
    # torch.backends.cudnn.deterministic = True
    # torch.backends.cudnn.benchmark = False

# %%
set_seed(42)

# %%
device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
# get mnist data
data_dir = './data'
os.makedirs(data_dir,exist_ok=True)
mnist_train_dataset = datasets.MNIST(data_dir, train=True, download=True, transform=transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))]))

# %%
# plot 9 random sample images from a mnist dataset (train or test)
def plot_9_sample_images(dataset):
    fig, axs = plt.subplots(3, 3)
    indices = np.random.choice(len(dataset), 9)
    for i, idx in enumerate(indices):
        axs[np.unravel_index(i, (3,3))].imshow(dataset[idx][0].squeeze(), cmap="gray")
        axs[np.unravel_index(i, (3,3))].set_title(f"label={dataset[idx][1]}")
        axs[np.unravel_index(i, (3,3))].set_axis_off()
    plt.show()
    

plot_9_sample_images(mnist_train_dataset)

# %%
# compute losses


def discriminator_loss(batch_real_data, batch_gen_data, discriminator_model):
    loss = nn.BCEWithLogitsLoss()
    logits_real = discriminator_model(batch_real_data)
    logits_fake = discriminator_model(batch_gen_data)
    loss_D  = loss(logits_real, torch.ones_like(logits_real).to(device)) + loss(logits_fake, torch.zeros_like(logits_fake).to(device))
    return loss_D, logits_real, logits_fake

def discriminator_wasserstein_loss(batch_real_data, batch_gen_data, discriminator_model):
    pass

def generator_loss(z, discriminator_model, generator_model):
    loss = nn.BCEWithLogitsLoss()
    batch_gen_data = generator_model(z)
    logits_fake = discriminator_model(batch_gen_data) 
    return loss(logits_fake, torch.ones_like(logits_fake).to(device))

# %%
# weights initialization
def weights_init_dcgan(m):    
    if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d, nn.Linear)):
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        if m.bias is not None:
            nn.init.constant_(m.bias.data, 0)

    elif isinstance(m, nn.BatchNorm1d) or isinstance(m, nn.BatchNorm2d):
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %%
# define model
generator = Generator()
generator.to(device)

discriminator = Discriminator()
discriminator.to(device)

generator.apply(weights_init_dcgan)
discriminator.apply(weights_init_dcgan)
# Out:
# Discriminator(
#   (down1): Conv2d(1, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (down2): Conv2d(256, 512, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (out): Conv2d(512, 1, kernel_size=(7, 7), stride=(1, 1))
# )

# %%
learning_rate = 2e-4
batch_size = 64
epochs = 20

# %%
train_dataloader = DataLoader(mnist_train_dataset, batch_size=batch_size)

# %%
# Display image and label.
print(f"length of the dataloader = {len(train_dataloader)}")
train_features, train_labels = next(iter(train_dataloader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
# Out:
# length of the dataloader = 938
# Feature batch shape: torch.Size([64, 1, 28, 28])
# Labels batch shape: torch.Size([64])

# %%
# optimizer
betas = (0.5, 0.999)
optimizer_G = torch.optim.Adam(generator.parameters(), learning_rate, betas)
optimizer_D = torch.optim.Adam(discriminator.parameters(), learning_rate, betas)

# %%
def update_D(real_data, gen_data, discriminator, number_of_update, optimizer_D):
    loss = 0
    D_real = 0
    D_fake = 0
    
    for i in range(number_of_update):
        optimizer_D.zero_grad()
        loss_D, logits_real, logits_fake = discriminator_loss(real_data, gen_data, discriminator)
        loss_D.backward()
        optimizer_D.step()
        loss = loss_D.item()
        with torch.no_grad():
            D_real = torch.sigmoid(logits_real).mean().item()
            D_fake = torch.sigmoid(logits_fake).mean().item()
        
    return loss, D_real, D_fake
    
        
def update_G(z, discriminator, generator, number_of_update, optimizer_G):
    loss = 0
    for i in range(number_of_update):
        optimizer_G.zero_grad()
        loss_G = generator_loss(z, discriminator, generator)
        loss_G.backward()
        optimizer_G.step()
        loss = loss_G.item()
    return loss

# %%
def training_loop(generator, discriminator, train_dataloader, epochs, batch_size, optimizer_G, optimizer_D):
    
    z_fixed = torch.randn(64, 100, device=device)
    os.makedirs("./output/samples",exist_ok=True)
    losses_D = []
    losses_G = []
    D_real_hist = []
    D_fake_hist = []

    for epoch in range(epochs):
        
        epoch_loss_D = 0 
        epoch_loss_G = 0 
        epoch_D_real = 0.0
        epoch_D_fake = 0.0
      
        generator.eval()
        with torch.no_grad():
            fake = generator(z_fixed).cpu()
        fake = (fake + 1) / 2  # [-1,1] → [0,1]
        save_image(fake, f"./output/samples/epoch_{epoch+1:03d}.png", nrow=8,  normalize=False)
        generator.train()
        
        for i, data in enumerate(train_dataloader):
            real_data, _ = data
            real_data = real_data.to(device)
            z = torch.rand((real_data.shape[0], 100)).to(device)
            gen_data = generator(z)
            gen_data_detached = gen_data.detach()

            loss_D, D_real, D_fake = update_D(real_data, gen_data_detached, discriminator, 1, optimizer_D)
            loss_G = update_G(z, discriminator, generator, 1, optimizer_G)
            
            epoch_loss_D += loss_D / len(train_dataloader)
            epoch_loss_G += loss_G / len(train_dataloader)
            epoch_D_real += D_real / len(train_dataloader)
            epoch_D_fake += D_fake / len(train_dataloader)
            
            if i%50==0:
                print(f'Epoch/Batch_index {epoch+1}/{i} batch_loss_D {loss_D:.3f}, batch_loss_G {loss_G:.3f}')
        losses_D.append(epoch_loss_D)
        losses_G.append(epoch_loss_G)
        D_real_hist.append(epoch_D_real)
        D_fake_hist.append(epoch_D_fake)

        print(
        f"Epoch {epoch+1:03d} | "
        f"Loss D: {epoch_loss_D:.4f} | "
        f"Loss G: {epoch_loss_G:.4f} | "
        f"D(real): {epoch_D_real:.3f} | "
        f"D(fake): {epoch_D_fake:.3f}"
        )
    
    return losses_D, losses_G, D_real_hist, D_fake_hist

# %%
losses_D, losses_G, D_real_hist, D_fake_hist = training_loop(generator, discriminator, train_dataloader, epochs, batch_size, optimizer_G, optimizer_D)
# Out:
# Epoch/Batch_index 1/0 batch_loss_D 2.134, batch_loss_G 9.490
# Epoch/Batch_index 1/50 batch_loss_D 2.427, batch_loss_G 14.543
# Epoch/Batch_index 1/100 batch_loss_D 1.053, batch_loss_G 1.160
# Epoch/Batch_index 1/150 batch_loss_D 1.484, batch_loss_G 1.138
# Epoch/Batch_index 1/200 batch_loss_D 0.955, batch_loss_G 2.729
# Epoch/Batch_index 1/250 batch_loss_D 0.858, batch_loss_G 0.940
# Epoch/Batch_index 1/300 batch_loss_D 1.056, batch_loss_G 0.659
# Epoch/Batch_index 1/350 batch_loss_D 0.520, batch_loss_G 1.452
# Epoch/Batch_index 1/400 batch_loss_D 0.799, batch_loss_G 3.489
# Epoch/Batch_index 1/450 batch_loss_D 0.316, batch_loss_G 2.498
# Epoch/Batch_index 1/500 batch_loss_D 1.385, batch_loss_G 6.157
# Epoch/Batch_index 1/550 batch_loss_D 0.620, batch_loss_G 3.596
# Epoch/Batch_index 1/600 batch_loss_D 0.469, batch_loss_G 2.531
# Epoch/Batch_index 1/650 batch_loss_D 0.765, batch_loss_G 1.573
# Epoch/Batch_index 1/700 batch_loss_D 1.371, batch_loss_G 3.612
# Epoch/Batch_index 1/750 batch_loss_D 1.305, batch_loss_G 2.899
# Epoch/Batch_index 1/800 batch_loss_D 1.177, batch_loss_G 1.155
# Epoch/Batch_index 1/850 batch_loss_D 1.075, batch_loss_G 2.434
# Epoch/Batch_index 1/900 batch_loss_D 0.763, batch_loss_G 1.818
# Epoch 001 | Loss D: 0.9195 | Loss G: 2.8308 | D(real): 0.736 | D(fake): 0.265
# Epoch/Batch_index 2/0 batch_loss_D 2.159, batch_loss_G 0.710
# Epoch/Batch_index 2/50 batch_loss_D 1.116, batch_loss_G 0.937
# Epoch/Batch_index 2/100 batch_loss_D 1.358, batch_loss_G 0.819
# Epoch/Batch_index 2/150 batch_loss_D 0.972, batch_loss_G 2.581
# Epoch/Batch_index 2/200 batch_loss_D 1.042, batch_loss_G 1.890
# Epoch/Batch_index 2/250 batch_loss_D 1.128, batch_loss_G 2.341
# Epoch/Batch_index 2/300 batch_loss_D 1.667, batch_loss_G 0.708
# Epoch/Batch_index 2/350 batch_loss_D 1.098, batch_loss_G 2.167
# Epoch/Batch_index 2/400 batch_loss_D 0.892, batch_loss_G 2.161
# Epoch/Batch_index 2/450 batch_loss_D 0.727, batch_loss_G 2.758
# Epoch/Batch_index 2/500 batch_loss_D 1.173, batch_loss_G 1.536
# Epoch/Batch_index 2/550 batch_loss_D 0.884, batch_loss_G 1.714
# Epoch/Batch_index 2/600 batch_loss_D 0.955, batch_loss_G 1.314
# Epoch/Batch_index 2/650 batch_loss_D 1.077, batch_loss_G 1.000
# Epoch/Batch_index 2/700 batch_loss_D 0.954, batch_loss_G 1.879
# Epoch/Batch_index 2/750 batch_loss_D 0.940, batch_loss_G 1.881
# Epoch/Batch_index 2/800 batch_loss_D 1.167, batch_loss_G 1.764
# Epoch/Batch_index 2/850 batch_loss_D 0.943, batch_loss_G 1.284
# Epoch/Batch_index 2/900 batch_loss_D 1.244, batch_loss_G 0.845
# Epoch 002 | Loss D: 1.0754 | Loss G: 1.6800 | D(real): 0.660 | D(fake): 0.340
# Epoch/Batch_index 3/0 batch_loss_D 1.727, batch_loss_G 0.743
# Epoch/Batch_index 3/50 batch_loss_D 1.120, batch_loss_G 1.197
# Epoch/Batch_index 3/100 batch_loss_D 1.462, batch_loss_G 1.267
# Epoch/Batch_index 3/150 batch_loss_D 1.258, batch_loss_G 2.282
# Epoch/Batch_index 3/200 batch_loss_D 1.046, batch_loss_G 1.116
# Epoch/Batch_index 3/250 batch_loss_D 1.071, batch_loss_G 1.629
# Epoch/Batch_index 3/300 batch_loss_D 1.055, batch_loss_G 1.278
# Epoch/Batch_index 3/350 batch_loss_D 1.015, batch_loss_G 1.323
# Epoch/Batch_index 3/400 batch_loss_D 1.142, batch_loss_G 1.600
# Epoch/Batch_index 3/450 batch_loss_D 0.734, batch_loss_G 2.245
# Epoch/Batch_index 3/500 batch_loss_D 1.505, batch_loss_G 1.587
# Epoch/Batch_index 3/550 batch_loss_D 0.911, batch_loss_G 1.647
# Epoch/Batch_index 3/600 batch_loss_D 1.122, batch_loss_G 1.429
# Epoch/Batch_index 3/650 batch_loss_D 0.946, batch_loss_G 1.520
# Epoch/Batch_index 3/700 batch_loss_D 1.103, batch_loss_G 1.156
# Epoch/Batch_index 3/750 batch_loss_D 1.321, batch_loss_G 1.313
# Epoch/Batch_index 3/800 batch_loss_D 1.173, batch_loss_G 1.534
# Epoch/Batch_index 3/850 batch_loss_D 1.121, batch_loss_G 1.357
# Epoch/Batch_index 3/900 batch_loss_D 1.167, batch_loss_G 0.890
# Epoch 003 | Loss D: 1.1711 | Loss G: 1.4672 | D(real): 0.625 | D(fake): 0.374
# Epoch/Batch_index 4/0 batch_loss_D 1.870, batch_loss_G 0.680
# Epoch/Batch_index 4/50 batch_loss_D 1.289, batch_loss_G 0.895
# Epoch/Batch_index 4/100 batch_loss_D 1.461, batch_loss_G 0.571
# Epoch/Batch_index 4/150 batch_loss_D 1.306, batch_loss_G 2.308
# Epoch/Batch_index 4/200 batch_loss_D 1.167, batch_loss_G 1.223
# Epoch/Batch_index 4/250 batch_loss_D 1.167, batch_loss_G 1.411
# Epoch/Batch_index 4/300 batch_loss_D 1.113, batch_loss_G 0.930
# Epoch/Batch_index 4/350 batch_loss_D 1.187, batch_loss_G 1.103
# Epoch/Batch_index 4/400 batch_loss_D 1.211, batch_loss_G 1.223
# Epoch/Batch_index 4/450 batch_loss_D 0.957, batch_loss_G 2.015
# Epoch/Batch_index 4/500 batch_loss_D 1.648, batch_loss_G 1.292
# Epoch/Batch_index 4/550 batch_loss_D 1.081, batch_loss_G 1.076
# Epoch/Batch_index 4/600 batch_loss_D 1.134, batch_loss_G 1.051
# Epoch/Batch_index 4/650 batch_loss_D 1.109, batch_loss_G 1.080
# Epoch/Batch_index 4/700 batch_loss_D 0.983, batch_loss_G 1.364
# Epoch/Batch_index 4/750 batch_loss_D 1.260, batch_loss_G 1.197
# Epoch/Batch_index 4/800 batch_loss_D 1.336, batch_loss_G 1.791
# Epoch/Batch_index 4/850 batch_loss_D 1.179, batch_loss_G 0.957
# Epoch/Batch_index 4/900 batch_loss_D 1.063, batch_loss_G 1.312
# Epoch 004 | Loss D: 1.2240 | Loss G: 1.3195 | D(real): 0.603 | D(fake): 0.397
# Epoch/Batch_index 5/0 batch_loss_D 1.685, batch_loss_G 0.535
# Epoch/Batch_index 5/50 batch_loss_D 1.247, batch_loss_G 0.933
# Epoch/Batch_index 5/100 batch_loss_D 1.379, batch_loss_G 0.952
# Epoch/Batch_index 5/150 batch_loss_D 1.007, batch_loss_G 1.571
# Epoch/Batch_index 5/200 batch_loss_D 1.361, batch_loss_G 1.746
# Epoch/Batch_index 5/250 batch_loss_D 1.230, batch_loss_G 1.328
# Epoch/Batch_index 5/300 batch_loss_D 1.228, batch_loss_G 1.164
# Epoch/Batch_index 5/350 batch_loss_D 1.339, batch_loss_G 0.715
# Epoch/Batch_index 5/400 batch_loss_D 1.300, batch_loss_G 1.170
# Epoch/Batch_index 5/450 batch_loss_D 1.043, batch_loss_G 1.741
# Epoch/Batch_index 5/500 batch_loss_D 1.575, batch_loss_G 1.299
# Epoch/Batch_index 5/550 batch_loss_D 1.034, batch_loss_G 1.141
# Epoch/Batch_index 5/600 batch_loss_D 1.240, batch_loss_G 1.466
# Epoch/Batch_index 5/650 batch_loss_D 1.241, batch_loss_G 1.496
# Epoch/Batch_index 5/700 batch_loss_D 1.087, batch_loss_G 1.420
# Epoch/Batch_index 5/750 batch_loss_D 1.067, batch_loss_G 1.272
# Epoch/Batch_index 5/800 batch_loss_D 1.422, batch_loss_G 1.606
# Epoch/Batch_index 5/850 batch_loss_D 1.312, batch_loss_G 1.157
# Epoch/Batch_index 5/900 batch_loss_D 1.100, batch_loss_G 1.131
# Epoch 005 | Loss D: 1.2509 | Loss G: 1.2558 | D(real): 0.593 | D(fake): 0.408
# Epoch/Batch_index 6/0 batch_loss_D 1.790, batch_loss_G 0.495
# Epoch/Batch_index 6/50 batch_loss_D 1.497, batch_loss_G 0.813
# Epoch/Batch_index 6/100 batch_loss_D 1.593, batch_loss_G 0.484
# Epoch/Batch_index 6/150 batch_loss_D 1.207, batch_loss_G 1.829
# Epoch/Batch_index 6/200 batch_loss_D 1.304, batch_loss_G 1.091
# Epoch/Batch_index 6/250 batch_loss_D 1.327, batch_loss_G 0.934
# Epoch/Batch_index 6/300 batch_loss_D 1.366, batch_loss_G 0.960
# Epoch/Batch_index 6/350 batch_loss_D 1.365, batch_loss_G 0.848
# Epoch/Batch_index 6/400 batch_loss_D 1.229, batch_loss_G 1.458
# Epoch/Batch_index 6/450 batch_loss_D 1.309, batch_loss_G 2.576
# Epoch/Batch_index 6/500 batch_loss_D 1.659, batch_loss_G 1.292
# Epoch/Batch_index 6/550 batch_loss_D 1.147, batch_loss_G 1.118
# Epoch/Batch_index 6/600 batch_loss_D 1.301, batch_loss_G 0.989
# Epoch/Batch_index 6/650 batch_loss_D 1.223, batch_loss_G 0.854
# Epoch/Batch_index 6/700 batch_loss_D 1.112, batch_loss_G 1.371
# Epoch/Batch_index 6/750 batch_loss_D 1.322, batch_loss_G 0.998
# Epoch/Batch_index 6/800 batch_loss_D 1.274, batch_loss_G 1.420
# Epoch/Batch_index 6/850 batch_loss_D 1.123, batch_loss_G 1.055
# Epoch/Batch_index 6/900 batch_loss_D 1.092, batch_loss_G 0.893
# Epoch 006 | Loss D: 1.2749 | Loss G: 1.2104 | D(real): 0.583 | D(fake): 0.417
# Epoch/Batch_index 7/0 batch_loss_D 1.981, batch_loss_G 0.401
# Epoch/Batch_index 7/50 batch_loss_D 1.272, batch_loss_G 0.971
# Epoch/Batch_index 7/100 batch_loss_D 1.281, batch_loss_G 0.739
# Epoch/Batch_index 7/150 batch_loss_D 0.979, batch_loss_G 1.656
# Epoch/Batch_index 7/200 batch_loss_D 1.283, batch_loss_G 1.085
# Epoch/Batch_index 7/250 batch_loss_D 1.338, batch_loss_G 1.065
# Epoch/Batch_index 7/300 batch_loss_D 1.235, batch_loss_G 0.861
# Epoch/Batch_index 7/350 batch_loss_D 1.261, batch_loss_G 0.903
# Epoch/Batch_index 7/400 batch_loss_D 1.326, batch_loss_G 1.340
# Epoch/Batch_index 7/450 batch_loss_D 1.024, batch_loss_G 1.937
# Epoch/Batch_index 7/500 batch_loss_D 1.911, batch_loss_G 1.123
# Epoch/Batch_index 7/550 batch_loss_D 1.123, batch_loss_G 1.322
# Epoch/Batch_index 7/600 batch_loss_D 1.359, batch_loss_G 0.935
# Epoch/Batch_index 7/650 batch_loss_D 1.257, batch_loss_G 1.164
# Epoch/Batch_index 7/700 batch_loss_D 1.188, batch_loss_G 0.970
# Epoch/Batch_index 7/750 batch_loss_D 1.325, batch_loss_G 1.026
# Epoch/Batch_index 7/800 batch_loss_D 1.396, batch_loss_G 1.405
# Epoch/Batch_index 7/850 batch_loss_D 1.235, batch_loss_G 1.036
# Epoch/Batch_index 7/900 batch_loss_D 1.172, batch_loss_G 0.958
# Epoch 007 | Loss D: 1.2867 | Loss G: 1.1746 | D(real): 0.577 | D(fake): 0.423
# Epoch/Batch_index 8/0 batch_loss_D 1.573, batch_loss_G 0.493
# Epoch/Batch_index 8/50 batch_loss_D 1.359, batch_loss_G 0.977
# Epoch/Batch_index 8/100 batch_loss_D 1.199, batch_loss_G 0.883
# Epoch/Batch_index 8/150 batch_loss_D 1.133, batch_loss_G 1.817
# Epoch/Batch_index 8/200 batch_loss_D 1.386, batch_loss_G 0.959
# Epoch/Batch_index 8/250 batch_loss_D 1.495, batch_loss_G 1.097
# Epoch/Batch_index 8/300 batch_loss_D 1.392, batch_loss_G 0.847
# Epoch/Batch_index 8/350 batch_loss_D 1.423, batch_loss_G 0.686
# Epoch/Batch_index 8/400 batch_loss_D 1.391, batch_loss_G 1.442
# Epoch/Batch_index 8/450 batch_loss_D 1.149, batch_loss_G 2.016
# Epoch/Batch_index 8/500 batch_loss_D 1.421, batch_loss_G 0.914
# Epoch/Batch_index 8/550 batch_loss_D 1.013, batch_loss_G 1.113
# Epoch/Batch_index 8/600 batch_loss_D 1.261, batch_loss_G 0.991
# Epoch/Batch_index 8/650 batch_loss_D 1.409, batch_loss_G 0.941
# Epoch/Batch_index 8/700 batch_loss_D 1.188, batch_loss_G 0.954
# Epoch/Batch_index 8/750 batch_loss_D 1.400, batch_loss_G 0.735
# Epoch/Batch_index 8/800 batch_loss_D 1.450, batch_loss_G 1.284
# Epoch/Batch_index 8/850 batch_loss_D 1.024, batch_loss_G 1.124
# Epoch/Batch_index 8/900 batch_loss_D 1.242, batch_loss_G 1.336
# Epoch 008 | Loss D: 1.3046 | Loss G: 1.1435 | D(real): 0.571 | D(fake): 0.429
# Epoch/Batch_index 9/0 batch_loss_D 1.716, batch_loss_G 0.509
# Epoch/Batch_index 9/50 batch_loss_D 1.335, batch_loss_G 0.911
# Epoch/Batch_index 9/100 batch_loss_D 1.320, batch_loss_G 0.743
# Epoch/Batch_index 9/150 batch_loss_D 1.140, batch_loss_G 1.419
# Epoch/Batch_index 9/200 batch_loss_D 1.429, batch_loss_G 1.146
# Epoch/Batch_index 9/250 batch_loss_D 1.400, batch_loss_G 1.175
# Epoch/Batch_index 9/300 batch_loss_D 1.488, batch_loss_G 0.683
# Epoch/Batch_index 9/350 batch_loss_D 1.307, batch_loss_G 0.941
# Epoch/Batch_index 9/400 batch_loss_D 1.238, batch_loss_G 1.308
# Epoch/Batch_index 9/450 batch_loss_D 1.055, batch_loss_G 1.466
# Epoch/Batch_index 9/500 batch_loss_D 1.843, batch_loss_G 1.076
# Epoch/Batch_index 9/550 batch_loss_D 1.205, batch_loss_G 1.075
# Epoch/Batch_index 9/600 batch_loss_D 1.422, batch_loss_G 1.073
# Epoch/Batch_index 9/650 batch_loss_D 1.275, batch_loss_G 1.044
# Epoch/Batch_index 9/700 batch_loss_D 1.160, batch_loss_G 1.393
# Epoch/Batch_index 9/750 batch_loss_D 1.329, batch_loss_G 0.784
# Epoch/Batch_index 9/800 batch_loss_D 1.428, batch_loss_G 1.312
# Epoch/Batch_index 9/850 batch_loss_D 1.257, batch_loss_G 1.304
# Epoch/Batch_index 9/900 batch_loss_D 1.179, batch_loss_G 1.364
# Epoch 009 | Loss D: 1.3138 | Loss G: 1.1126 | D(real): 0.566 | D(fake): 0.434
# Epoch/Batch_index 10/0 batch_loss_D 1.691, batch_loss_G 0.647
# Epoch/Batch_index 10/50 batch_loss_D 1.524, batch_loss_G 1.153
# Epoch/Batch_index 10/100 batch_loss_D 1.362, batch_loss_G 0.809
# Epoch/Batch_index 10/150 batch_loss_D 1.022, batch_loss_G 1.335
# Epoch/Batch_index 10/200 batch_loss_D 1.487, batch_loss_G 0.956
# Epoch/Batch_index 10/250 batch_loss_D 1.353, batch_loss_G 1.113
# Epoch/Batch_index 10/300 batch_loss_D 1.402, batch_loss_G 0.700
# Epoch/Batch_index 10/350 batch_loss_D 1.327, batch_loss_G 0.824
# Epoch/Batch_index 10/400 batch_loss_D 1.273, batch_loss_G 1.218
# Epoch/Batch_index 10/450 batch_loss_D 1.186, batch_loss_G 1.810
# Epoch/Batch_index 10/500 batch_loss_D 1.790, batch_loss_G 1.086
# Epoch/Batch_index 10/550 batch_loss_D 1.161, batch_loss_G 1.052
# Epoch/Batch_index 10/600 batch_loss_D 1.296, batch_loss_G 1.084
# Epoch/Batch_index 10/650 batch_loss_D 1.212, batch_loss_G 1.106
# Epoch/Batch_index 10/700 batch_loss_D 1.171, batch_loss_G 1.086
# Epoch/Batch_index 10/750 batch_loss_D 1.395, batch_loss_G 0.674
# Epoch/Batch_index 10/800 batch_loss_D 1.399, batch_loss_G 1.158
# Epoch/Batch_index 10/850 batch_loss_D 1.103, batch_loss_G 0.898
# Epoch/Batch_index 10/900 batch_loss_D 1.154, batch_loss_G 1.025
# Epoch 010 | Loss D: 1.3134 | Loss G: 1.0960 | D(real): 0.563 | D(fake): 0.437
# Epoch/Batch_index 11/0 batch_loss_D 1.749, batch_loss_G 0.554
# Epoch/Batch_index 11/50 batch_loss_D 1.356, batch_loss_G 0.812
# Epoch/Batch_index 11/100 batch_loss_D 1.396, batch_loss_G 0.670
# Epoch/Batch_index 11/150 batch_loss_D 1.203, batch_loss_G 1.573
# Epoch/Batch_index 11/200 batch_loss_D 1.481, batch_loss_G 0.893
# Epoch/Batch_index 11/250 batch_loss_D 1.356, batch_loss_G 1.039
# Epoch/Batch_index 11/300 batch_loss_D 1.439, batch_loss_G 0.798
# Epoch/Batch_index 11/350 batch_loss_D 1.277, batch_loss_G 0.845
# Epoch/Batch_index 11/400 batch_loss_D 1.385, batch_loss_G 1.291
# Epoch/Batch_index 11/450 batch_loss_D 0.979, batch_loss_G 1.666
# Epoch/Batch_index 11/500 batch_loss_D 1.743, batch_loss_G 1.021
# Epoch/Batch_index 11/550 batch_loss_D 1.238, batch_loss_G 1.158
# Epoch/Batch_index 11/600 batch_loss_D 1.362, batch_loss_G 1.200
# Epoch/Batch_index 11/650 batch_loss_D 1.412, batch_loss_G 1.059
# Epoch/Batch_index 11/700 batch_loss_D 1.257, batch_loss_G 0.951
# Epoch/Batch_index 11/750 batch_loss_D 1.417, batch_loss_G 0.717
# Epoch/Batch_index 11/800 batch_loss_D 1.451, batch_loss_G 1.385
# Epoch/Batch_index 11/850 batch_loss_D 1.170, batch_loss_G 1.047
# Epoch/Batch_index 11/900 batch_loss_D 1.252, batch_loss_G 1.086
# Epoch 011 | Loss D: 1.3214 | Loss G: 1.0849 | D(real): 0.561 | D(fake): 0.439
# Epoch/Batch_index 12/0 batch_loss_D 1.864, batch_loss_G 0.348
# Epoch/Batch_index 12/50 batch_loss_D 1.353, batch_loss_G 0.904
# Epoch/Batch_index 12/100 batch_loss_D 1.412, batch_loss_G 0.742
# Epoch/Batch_index 12/150 batch_loss_D 1.126, batch_loss_G 1.340
# Epoch/Batch_index 12/200 batch_loss_D 1.437, batch_loss_G 0.954
# Epoch/Batch_index 12/250 batch_loss_D 1.341, batch_loss_G 1.239
# Epoch/Batch_index 12/300 batch_loss_D 1.532, batch_loss_G 0.805
# Epoch/Batch_index 12/350 batch_loss_D 1.409, batch_loss_G 0.889
# Epoch/Batch_index 12/400 batch_loss_D 1.197, batch_loss_G 1.168
# Epoch/Batch_index 12/450 batch_loss_D 1.053, batch_loss_G 1.652
# Epoch/Batch_index 12/500 batch_loss_D 1.671, batch_loss_G 1.059
# Epoch/Batch_index 12/550 batch_loss_D 1.060, batch_loss_G 1.055
# Epoch/Batch_index 12/600 batch_loss_D 1.390, batch_loss_G 1.047
# Epoch/Batch_index 12/650 batch_loss_D 1.315, batch_loss_G 1.078
# Epoch/Batch_index 12/700 batch_loss_D 1.319, batch_loss_G 1.015
# Epoch/Batch_index 12/750 batch_loss_D 1.415, batch_loss_G 0.731
# Epoch/Batch_index 12/800 batch_loss_D 1.343, batch_loss_G 1.277
# Epoch/Batch_index 12/850 batch_loss_D 1.077, batch_loss_G 1.223
# Epoch/Batch_index 12/900 batch_loss_D 1.161, batch_loss_G 1.079
# Epoch 012 | Loss D: 1.3208 | Loss G: 1.0725 | D(real): 0.559 | D(fake): 0.440
# Epoch/Batch_index 13/0 batch_loss_D 1.653, batch_loss_G 0.425
# Epoch/Batch_index 13/50 batch_loss_D 1.453, batch_loss_G 0.916
# Epoch/Batch_index 13/100 batch_loss_D 1.456, batch_loss_G 0.924
# Epoch/Batch_index 13/150 batch_loss_D 1.146, batch_loss_G 1.453
# Epoch/Batch_index 13/200 batch_loss_D 1.504, batch_loss_G 0.890
# Epoch/Batch_index 13/250 batch_loss_D 1.316, batch_loss_G 1.157
# Epoch/Batch_index 13/300 batch_loss_D 1.412, batch_loss_G 0.832
# Epoch/Batch_index 13/350 batch_loss_D 1.547, batch_loss_G 0.717
# Epoch/Batch_index 13/400 batch_loss_D 1.381, batch_loss_G 1.364
# Epoch/Batch_index 13/450 batch_loss_D 0.983, batch_loss_G 1.307
# Epoch/Batch_index 13/500 batch_loss_D 1.791, batch_loss_G 1.112
# Epoch/Batch_index 13/550 batch_loss_D 1.186, batch_loss_G 0.924
# Epoch/Batch_index 13/600 batch_loss_D 1.354, batch_loss_G 0.984
# Epoch/Batch_index 13/650 batch_loss_D 1.283, batch_loss_G 1.131
# Epoch/Batch_index 13/700 batch_loss_D 1.307, batch_loss_G 1.091
# Epoch/Batch_index 13/750 batch_loss_D 1.500, batch_loss_G 0.621
# Epoch/Batch_index 13/800 batch_loss_D 1.381, batch_loss_G 0.918
# Epoch/Batch_index 13/850 batch_loss_D 1.068, batch_loss_G 1.154
# Epoch/Batch_index 13/900 batch_loss_D 1.221, batch_loss_G 1.039
# Epoch 013 | Loss D: 1.3239 | Loss G: 1.0598 | D(real): 0.558 | D(fake): 0.442
# Epoch/Batch_index 14/0 batch_loss_D 1.876, batch_loss_G 0.490
# Epoch/Batch_index 14/50 batch_loss_D 1.519, batch_loss_G 0.833
# Epoch/Batch_index 14/100 batch_loss_D 1.601, batch_loss_G 0.639
# Epoch/Batch_index 14/150 batch_loss_D 1.112, batch_loss_G 1.354
# Epoch/Batch_index 14/200 batch_loss_D 1.492, batch_loss_G 1.205
# Epoch/Batch_index 14/250 batch_loss_D 1.509, batch_loss_G 1.163
# Epoch/Batch_index 14/300 batch_loss_D 1.392, batch_loss_G 0.925
# Epoch/Batch_index 14/350 batch_loss_D 1.363, batch_loss_G 0.939
# Epoch/Batch_index 14/400 batch_loss_D 1.285, batch_loss_G 1.322
# Epoch/Batch_index 14/450 batch_loss_D 1.045, batch_loss_G 1.512
# Epoch/Batch_index 14/500 batch_loss_D 1.715, batch_loss_G 1.164
# Epoch/Batch_index 14/550 batch_loss_D 1.193, batch_loss_G 1.112
# Epoch/Batch_index 14/600 batch_loss_D 1.388, batch_loss_G 1.078
# Epoch/Batch_index 14/650 batch_loss_D 1.448, batch_loss_G 0.843
# Epoch/Batch_index 14/700 batch_loss_D 1.170, batch_loss_G 1.249
# Epoch/Batch_index 14/750 batch_loss_D 1.402, batch_loss_G 0.698
# Epoch/Batch_index 14/800 batch_loss_D 1.452, batch_loss_G 1.244
# Epoch/Batch_index 14/850 batch_loss_D 1.166, batch_loss_G 0.949
# Epoch/Batch_index 14/900 batch_loss_D 1.188, batch_loss_G 1.226
# Epoch 014 | Loss D: 1.3262 | Loss G: 1.0538 | D(real): 0.557 | D(fake): 0.443
# Epoch/Batch_index 15/0 batch_loss_D 1.902, batch_loss_G 0.518
# Epoch/Batch_index 15/50 batch_loss_D 1.428, batch_loss_G 0.965
# Epoch/Batch_index 15/100 batch_loss_D 1.419, batch_loss_G 0.788
# Epoch/Batch_index 15/150 batch_loss_D 1.110, batch_loss_G 1.187
# Epoch/Batch_index 15/200 batch_loss_D 1.335, batch_loss_G 1.158
# Epoch/Batch_index 15/250 batch_loss_D 1.450, batch_loss_G 1.215
# Epoch/Batch_index 15/300 batch_loss_D 1.347, batch_loss_G 0.841
# Epoch/Batch_index 15/350 batch_loss_D 1.355, batch_loss_G 0.794
# Epoch/Batch_index 15/400 batch_loss_D 1.284, batch_loss_G 1.312
# Epoch/Batch_index 15/450 batch_loss_D 1.151, batch_loss_G 1.396
# Epoch/Batch_index 15/500 batch_loss_D 1.774, batch_loss_G 0.846
# Epoch/Batch_index 15/550 batch_loss_D 1.166, batch_loss_G 1.090
# Epoch/Batch_index 15/600 batch_loss_D 1.322, batch_loss_G 1.227
# Epoch/Batch_index 15/650 batch_loss_D 1.333, batch_loss_G 0.961
# Epoch/Batch_index 15/700 batch_loss_D 1.191, batch_loss_G 0.949
# Epoch/Batch_index 15/750 batch_loss_D 1.298, batch_loss_G 0.864
# Epoch/Batch_index 15/800 batch_loss_D 1.334, batch_loss_G 1.258
# Epoch/Batch_index 15/850 batch_loss_D 1.182, batch_loss_G 1.111
# Epoch/Batch_index 15/900 batch_loss_D 1.242, batch_loss_G 1.091
# Epoch 015 | Loss D: 1.3250 | Loss G: 1.0418 | D(real): 0.556 | D(fake): 0.444
# Epoch/Batch_index 16/0 batch_loss_D 1.727, batch_loss_G 0.408
# Epoch/Batch_index 16/50 batch_loss_D 1.418, batch_loss_G 0.780
# Epoch/Batch_index 16/100 batch_loss_D 1.320, batch_loss_G 0.780
# Epoch/Batch_index 16/150 batch_loss_D 1.183, batch_loss_G 1.213
# Epoch/Batch_index 16/200 batch_loss_D 1.398, batch_loss_G 1.149
# Epoch/Batch_index 16/250 batch_loss_D 1.445, batch_loss_G 1.010
# Epoch/Batch_index 16/300 batch_loss_D 1.312, batch_loss_G 1.083
# Epoch/Batch_index 16/350 batch_loss_D 1.253, batch_loss_G 1.039
# Epoch/Batch_index 16/400 batch_loss_D 1.226, batch_loss_G 1.178
# Epoch/Batch_index 16/450 batch_loss_D 1.233, batch_loss_G 1.568
# Epoch/Batch_index 16/500 batch_loss_D 1.797, batch_loss_G 0.923
# Epoch/Batch_index 16/550 batch_loss_D 1.184, batch_loss_G 1.087
# Epoch/Batch_index 16/600 batch_loss_D 1.360, batch_loss_G 1.111
# Epoch/Batch_index 16/650 batch_loss_D 1.402, batch_loss_G 0.832
# Epoch/Batch_index 16/700 batch_loss_D 1.394, batch_loss_G 1.190
# Epoch/Batch_index 16/750 batch_loss_D 1.266, batch_loss_G 0.779
# Epoch/Batch_index 16/800 batch_loss_D 1.392, batch_loss_G 0.899
# Epoch/Batch_index 16/850 batch_loss_D 1.195, batch_loss_G 1.115
# Epoch/Batch_index 16/900 batch_loss_D 1.190, batch_loss_G 1.098
# Epoch 016 | Loss D: 1.3240 | Loss G: 1.0333 | D(real): 0.555 | D(fake): 0.445
# Epoch/Batch_index 17/0 batch_loss_D 1.846, batch_loss_G 0.416
# Epoch/Batch_index 17/50 batch_loss_D 1.517, batch_loss_G 0.819
# Epoch/Batch_index 17/100 batch_loss_D 1.438, batch_loss_G 0.758
# Epoch/Batch_index 17/150 batch_loss_D 1.143, batch_loss_G 1.231
# Epoch/Batch_index 17/200 batch_loss_D 1.479, batch_loss_G 1.141
# Epoch/Batch_index 17/250 batch_loss_D 1.390, batch_loss_G 1.033
# Epoch/Batch_index 17/300 batch_loss_D 1.450, batch_loss_G 0.717
# Epoch/Batch_index 17/350 batch_loss_D 1.303, batch_loss_G 0.964
# Epoch/Batch_index 17/400 batch_loss_D 1.410, batch_loss_G 1.369
# Epoch/Batch_index 17/450 batch_loss_D 1.065, batch_loss_G 1.334
# Epoch/Batch_index 17/500 batch_loss_D 1.945, batch_loss_G 1.119
# Epoch/Batch_index 17/550 batch_loss_D 1.171, batch_loss_G 1.246
# Epoch/Batch_index 17/600 batch_loss_D 1.372, batch_loss_G 0.980
# Epoch/Batch_index 17/650 batch_loss_D 1.373, batch_loss_G 1.002
# Epoch/Batch_index 17/700 batch_loss_D 1.178, batch_loss_G 0.983
# Epoch/Batch_index 17/750 batch_loss_D 1.288, batch_loss_G 0.861
# Epoch/Batch_index 17/800 batch_loss_D 1.360, batch_loss_G 1.216
# Epoch/Batch_index 17/850 batch_loss_D 1.176, batch_loss_G 1.063
# Epoch/Batch_index 17/900 batch_loss_D 1.227, batch_loss_G 0.874
# Epoch 017 | Loss D: 1.3228 | Loss G: 1.0358 | D(real): 0.555 | D(fake): 0.445
# Epoch/Batch_index 18/0 batch_loss_D 1.944, batch_loss_G 0.334
# Epoch/Batch_index 18/50 batch_loss_D 1.508, batch_loss_G 0.758
# Epoch/Batch_index 18/100 batch_loss_D 1.510, batch_loss_G 0.835
# Epoch/Batch_index 18/150 batch_loss_D 1.139, batch_loss_G 1.329
# Epoch/Batch_index 18/200 batch_loss_D 1.369, batch_loss_G 0.882
# Epoch/Batch_index 18/250 batch_loss_D 1.460, batch_loss_G 0.850
# Epoch/Batch_index 18/300 batch_loss_D 1.352, batch_loss_G 0.862
# Epoch/Batch_index 18/350 batch_loss_D 1.259, batch_loss_G 0.997
# Epoch/Batch_index 18/400 batch_loss_D 1.380, batch_loss_G 1.288
# Epoch/Batch_index 18/450 batch_loss_D 1.303, batch_loss_G 1.460
# Epoch/Batch_index 18/500 batch_loss_D 1.881, batch_loss_G 0.960
# Epoch/Batch_index 18/550 batch_loss_D 1.156, batch_loss_G 1.045
# Epoch/Batch_index 18/600 batch_loss_D 1.329, batch_loss_G 1.142
# Epoch/Batch_index 18/650 batch_loss_D 1.373, batch_loss_G 1.018
# Epoch/Batch_index 18/700 batch_loss_D 1.193, batch_loss_G 1.056
# Epoch/Batch_index 18/750 batch_loss_D 1.307, batch_loss_G 0.872
# Epoch/Batch_index 18/800 batch_loss_D 1.362, batch_loss_G 1.007
# Epoch/Batch_index 18/850 batch_loss_D 1.149, batch_loss_G 1.134
# Epoch/Batch_index 18/900 batch_loss_D 1.209, batch_loss_G 0.994
# Epoch 018 | Loss D: 1.3195 | Loss G: 1.0319 | D(real): 0.555 | D(fake): 0.445
# Epoch/Batch_index 19/0 batch_loss_D 1.865, batch_loss_G 0.354
# Epoch/Batch_index 19/50 batch_loss_D 1.453, batch_loss_G 0.966
# Epoch/Batch_index 19/100 batch_loss_D 1.537, batch_loss_G 0.652
# Epoch/Batch_index 19/150 batch_loss_D 1.079, batch_loss_G 1.300
# Epoch/Batch_index 19/200 batch_loss_D 1.626, batch_loss_G 1.237
# Epoch/Batch_index 19/250 batch_loss_D 1.435, batch_loss_G 1.151
# Epoch/Batch_index 19/300 batch_loss_D 1.386, batch_loss_G 0.855
# Epoch/Batch_index 19/350 batch_loss_D 1.272, batch_loss_G 1.058
# Epoch/Batch_index 19/400 batch_loss_D 1.329, batch_loss_G 1.296
# Epoch/Batch_index 19/450 batch_loss_D 1.172, batch_loss_G 1.374
# Epoch/Batch_index 19/500 batch_loss_D 1.650, batch_loss_G 0.942
# Epoch/Batch_index 19/550 batch_loss_D 1.029, batch_loss_G 1.068
# Epoch/Batch_index 19/600 batch_loss_D 1.342, batch_loss_G 1.021
# Epoch/Batch_index 19/650 batch_loss_D 1.384, batch_loss_G 0.957
# Epoch/Batch_index 19/700 batch_loss_D 1.126, batch_loss_G 1.031
# Epoch/Batch_index 19/750 batch_loss_D 1.378, batch_loss_G 0.650
# Epoch/Batch_index 19/800 batch_loss_D 1.390, batch_loss_G 0.995
# Epoch/Batch_index 19/850 batch_loss_D 1.052, batch_loss_G 1.194
# Epoch/Batch_index 19/900 batch_loss_D 1.236, batch_loss_G 1.050
# Epoch 019 | Loss D: 1.3203 | Loss G: 1.0312 | D(real): 0.555 | D(fake): 0.445
# Epoch/Batch_index 20/0 batch_loss_D 1.659, batch_loss_G 0.472
# Epoch/Batch_index 20/50 batch_loss_D 1.454, batch_loss_G 0.696
# Epoch/Batch_index 20/100 batch_loss_D 1.536, batch_loss_G 0.714
# Epoch/Batch_index 20/150 batch_loss_D 1.170, batch_loss_G 1.206
# Epoch/Batch_index 20/200 batch_loss_D 1.440, batch_loss_G 1.014
# Epoch/Batch_index 20/250 batch_loss_D 1.503, batch_loss_G 0.974
# Epoch/Batch_index 20/300 batch_loss_D 1.431, batch_loss_G 0.810
# Epoch/Batch_index 20/350 batch_loss_D 1.274, batch_loss_G 0.950
# Epoch/Batch_index 20/400 batch_loss_D 1.174, batch_loss_G 1.171
# Epoch/Batch_index 20/450 batch_loss_D 1.237, batch_loss_G 1.495
# Epoch/Batch_index 20/500 batch_loss_D 1.738, batch_loss_G 1.003
# Epoch/Batch_index 20/550 batch_loss_D 1.190, batch_loss_G 1.074
# Epoch/Batch_index 20/600 batch_loss_D 1.421, batch_loss_G 0.879
# Epoch/Batch_index 20/650 batch_loss_D 1.382, batch_loss_G 0.859
# Epoch/Batch_index 20/700 batch_loss_D 1.221, batch_loss_G 0.948
# Epoch/Batch_index 20/750 batch_loss_D 1.341, batch_loss_G 1.133
# Epoch/Batch_index 20/800 batch_loss_D 1.425, batch_loss_G 0.924
# Epoch/Batch_index 20/850 batch_loss_D 1.164, batch_loss_G 0.944
# Epoch/Batch_index 20/900 batch_loss_D 1.178, batch_loss_G 0.812
# Epoch 020 | Loss D: 1.3160 | Loss G: 1.0287 | D(real): 0.555 | D(fake): 0.445

# %%
plt.figure(figsize=(8, 5))
plt.plot(losses_D, label="Discriminator", linewidth=2)
plt.plot(losses_G, label="Generator", linewidth=2)

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("DCGAN Training Losses")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig("training_losses.png", dpi=150)
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.plot(D_real_hist, label="D(real)")
plt.plot(D_fake_hist, label="D(fake)")
plt.axhline(0.5, linestyle="--", color="gray")

plt.xlabel("Epoch")
plt.ylabel("Probability")
plt.title("Discriminator Confidence")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig("discriminator_confidence.png", dpi=150)
plt.show()

# %%
# see what is generated 
z = torch.rand(9,100).to(device)

generator.eval()
generated_images = generator(z)
generated_images = generated_images.cpu()
print(generated_images.shape)

fig, axs = plt.subplots(3, 3)
for i in range(generated_images.shape[0]):
    axs[np.unravel_index(i, (3,3))].imshow(generated_images[i].squeeze().detach().numpy(), cmap="gray")
    axs[np.unravel_index(i, (3,3))].set_axis_off()
plt.show()
# Out:
# torch.Size([9, 1, 28, 28])
